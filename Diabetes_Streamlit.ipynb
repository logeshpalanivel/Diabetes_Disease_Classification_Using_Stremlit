# %%
# !pip install streamlit -q

# %%
# !wget -q -O - ipv4.icanhazip.com

# %%
# %%writefile DecisionTree_app.py

# %%
# !npm install localtunnel

# %%
# !streamlit run DecisionTree_app.py &npx localtunnel --port 8501
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.29.93.195:8501
#
# npx: installed 22 in 2.047s
# your url is: https://silly-wombats-sleep.loca.lt
# 2024-07-02 10:23:21.645 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/DecisionTree_app.py", line 4, in <module>
#     model = pickle.load(open('model.pkl','rb'))
# FileNotFoundError: [Errno 2] No such file or directory: 'model.pkl'
# 2024-07-02 10:25:51.797 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/DecisionTree_app.py", line 4, in <module>
# ...
